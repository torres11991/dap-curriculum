# %% [markdown]
# # Intro to Python 3 and Jupyter Notebook
#
# The OBJECTIVES of This Section: Learn about ...
#
# - Data Analytics Intro to Python 3
#     -   What is Python?
#     -   Debugging
# - Achieving easier production flow in Jupyter Notebook
#     -   What is Jupyter Notebook
#     -   Installing Jupyter Notebook
#     -   How to use Jupyter Notebook
#
# <br>
#
# ---
#
# <br>

# %% [markdown]
# ## Why Data Analytics and Python?
#
# #### Well, what is a Programer?
#
# A computer programmer or a coder, is a person who creates computer programs — often to solve large problems.
#
# As such, a programer is a creator, a problem solver, and a thinker.
#
# #### And what is an Data Analyst?
#
# A Data Analysts conducts research and analyze collected data to find patterns, trends, and insights that can help answer question in decision-making and planning.
#
# So at the heart of it an analyst is also a thinker, a problem solver, and a creator.
#
# **This is why Programing and Data Analysis fit together so well!**
#
# ### And that is what we'll learn in this cohort
# -   We'll learn to think methodically
# -   How to create small programs to apply your coding skills
# -   And how to answer questions that solve problems
#
# ### What are Programs and Algorithms?
# -   An algorithm is a series of steps to solve a problem at hand
# -   A program is a series of instructions telling a computer how to solve a problem
#
# If we put this all together, then programming is the skill that allows a computer scientist to take an algorithm and represent that solution in a program that can be followed by a computer!
#
# Programs are written in programming languages such as Python, JavaScript, C# etc.

# %% [markdown]
# ## What is Python?
#
# **Python is considered a high-level language.**
#
# Programs must be processed before they can be run by a computer.
#
# The languages that are most easily understood by computers are the "lowest level languages" known as **Machine Languages**. These Machine Languages decode instructions into binary code that is easily interpreted and executed by computer hardware.
#
# While computers love low-level / machine languages, for us humans, it's easier to use a high-level coding language.
#
# High-level coding languages are more like natural languages
# -   they take less time to write
# -   they are shorter and easier to read
# -   and they are more likely to be correct/error free when we run them
#
# The drawback with High-level languages is that they need to be “translate” into machine language for computers to understand.
#
# ### There are two "ways" computers Process/Translate Program Code
#
# There are 2 general classes of coding languages --  `Interpreted` languages amd `Compiled` languages
#
# With **Interpreted Languages**, an interpreter reads a high-level program and executes it, meaning it does what the program says. Interpreters processes programs a little bit at a time, reading lines and performing computations.
#
# With **Compiled Languages**, a Compiler reads the whole program at once, and then translates it completely into machine code, before starting to run the program.
#
# ### Python is an Interpreted language
#
# The source code of a Python program is 'interpreted' a bit at a time, and converted into `byteCode`, that is then executed by the Python virtual machine.
#
# Python is different from major compiled languages, such as Java, C# and C++; Python code is not required to be built and linked like code for these other languages.
#
# ### Types of Languages
#
# Generally there are two classes of languages, `Natural` Languages and `Formal` Languages
#
# **Natural Languages** are mostly spoken languages that form on their own. Slang is a great example of a natural language.
#
# **Formal Languages** are designed by people. Programming languages fall under this category. For these languages there are formal rules about grammar, syntax, and punctuation.
#
# We are going to be learning all about the formal grammar, syntax, and punctuation of the Python language.
#
# ### Common Programing Vocabulary
#
# - **VALUE** -- a number or string etc. that can be stored in a variable or computed in an expression
# - **VARIABLE** -- a name that refers to a value
# - **VARIABLE NAME** -- A name given to a variable. Variable names consist of a sequence of letters and digits that begin with a letter. “In best programming practice", variable names should describe their use in a program, making the program self documenting
# - **str** -- a Python data type that holds a string of characters
# - **Operators** -- are special symbols that represent a simple computation
# - **Data Type** -- a set of values
# - **Comment** -- information in a program that is meant for other programmers and for your future-self (used with `#` in front)
# - **Input** -- a command in a program that prompts the user to put in an answer
# - **Output** -- the result of a program
#
# <br>
#
# ---
#
# ### Python Learning Materials
#
# The Python class materials we'll use are based on an open-source training program called **"Python For Everyone"** -- PY4E.
# - The PY4E program was created by Dr. Charles Severance (a.k.a. Dr. Chuck)
# - He’s a Clinical Professor at the University of Michigan School of Information Technology
# - The [PY4E website](https://www.py4e.com/) at https://www.py4e.com/ is loaded with additional training materials we recommend you use in parallel with this cohort
#
# > **You’ve chosen to learn another language! Be patient with yourself, and keep practicing!**

# %% [markdown]
# ---
#
# ![Let's write code](./images/letsWriteCode.png)
#
# ### Different ways to code Python
#
# There are several ways to code Python.
#
# - One can code and run Python code in an 'Integrated Development Environment' (IDE). We will use the VS Code IDE to do most of our coding. We will get to this a little later.
# - Python also comes with a built-in command-line interpreter where one can run Python commands and execute Python files.
#
# #### **Python Integrated Interpreter**
#
# The most straightforward way to start working with Python is in an interactive **Read-Eval-Print Loop (REPL)** environment. That simply means starting up the interpreter and typing commands to it directly.
#
# The interpreter:
# -   **Reads** the command you enter
# -   **Evaluates** and executes the command
# -   **Prints** the output (if any) to the console
# -   **Loops** back and repeats the process
#
# ---
#
# #### **Terminal Exercise: -**
#
# -   In your terminal, type the command "`python`". Note that for MacOS users the command is "`python3`".
# -   The python interpreter should open and display an image like this one below...
#
# ![Integrated Python Shell](./images/python_shell.png)
#
# -   The terminal should return something like the following response:-
#
# ```terminal
#     Type "help", "copyright", "credits" or "license" for more information.
# ```
#
# -   Type in the command "`help()`". The terminal should display a message like the one below...
#
# ![Python terminal help command](./images/python_shell_Help.png)
#
# - At the "help>" prompt type the command `keywords` and observe the response. You should see a list of Python reserved keywords (more about these later)
# - To quit this help utility and return to the interpreter, just type the command `quit` at the "help>" prompt
#
# **Next, let's execute the statement that displays "Hello, World!" to the console:-**
#
# -   Ensure that the >>> prompt is displayed, and the cursor is positioned after it
# -   Type the command `print("Hello, World!")` exactly as shown, and enter
# -   The interpreter’s response should appear on the next line. You can tell it is console output because the >>> prompt is absent:
#
# ![Hello World](./images/python_helloWorld.png)
#
# If your session looks like the above, then you have executed your first Python code! Take a moment to celebrate.
#
# When you are finished coding with the interpreter, you can exit the REPL session by typing `exit()` and pressing enter, or by pressing the `Ctrl+z` keys together.
#
# <br>
#
# ---

# %% [markdown]
# #### **Python in the VS Code IDE**
#
# An Integrated Development Environment (IDE) is an application that combines all the functionality of a REPL as well as an editor with which you can create and modify code to then submit to the interpreter for execution.
#
# In and IDE you may also find other cool features such as:
#
# - **Syntax highlighting**: IDEs often colorize different syntax elements in the code to make it easier to read
# - **Context-sensitive help**: Advanced IDEs can display related information from the Python documentation or even suggested fixes for common types of code errors
# - **Code-completion**: Some IDEs can complete partially typed pieces of code (like function names) for you—a great time-saver and convenience feature
# - **Debugging**: A debugger allows you to run code step-by-step and inspect program data as you go. This is invaluable when you are trying to determine why a program is behaving improperly, as will inevitably happen
#
# <br>
#
# ---
#
# #### **VS Code Exercise: -**
#
# - Make sure you’re in your "SavvyCoders" directory, and type "`code .`" to open VS Code in that directory
# - Once VS Code opens, create a new folder called "activities"
# - In this new folder, create a file called "`hello.py`"
# - Let us walk through how to code in this new file together
# - Type the command `print("Hello, World!")`
# - Save the file
# - We'll run this code  in 2 different ways
#     -   from our bash terminal
#     -   from within VS Code
#
# ##### **In your Bash terminal:-**
# 1. Navigate into the directory where you created the "`hello.py`" file
# 1. In the terminal type the following command to execute the file ... "`python hello.py`"
# > Note: For MacOS use the command "`python3 hello.py`"
#
# ##### **In VS Code:-**
# 1. Open a terminal inside VS Code
# 1. Make sure the terminal opens in the correct directory. If not, navigate into the correct directory
# 1. In the terminal type the command to run the file -- "`python hello.py`" (MacOS -- "`python3 hello.py`")
#
# <br>

# %% [markdown]
# ---
#
# ## Debugging Code
#
# Debugging is the process of detecting and removing existing and potential errors (aka 'bugs’) from software code.
#
# Errors could cause code to behave unexpectedly or crash.
#
# ### Examples of Error Types
#
# - **SYNTAX errors** – mistakes in the code like spelling, punctuation, spacing, incorrect labels, etc. The program won’t run
# - **RUNTIME errors** – occurs at the time of running or executing a program; program may hang or crash
# - **SEMANTIC errors** – code is grammatically correct but doesn't make any sense; it does not produce the expected results
# - **LOGICAL errors** –when instructions given do not accomplish the intended goal. EG: wrong calculations
#
# ### Debugging is a foundational skill
#
# Debugging  is a VERY useful -- even essential -- skill in programming.
#
# - It’s a science and an art
# - Think of yourself as a detective looking for the clues as to what went wrong
# - Consider all the evidence
# - Sometimes issues are minor and are quick to fix, but other issues could take a while to find / fix
# - The #1 Rule: Complexity is the enemy of efficiency!
#
# ### Helpful Debugging Tips
#
# - Regularly test and review code as you are writing it
# - Chunk code into smaller sections and make sure each section works
# - Explain your code aloud to yourself as if you are a 5-year-old
# - Work backward to try finding the issue
# - Take an break and come back to it when you run out of ideas
# - Ask someone to help you look at the code
#
# <br>

# %% [markdown]
# ---
#
# ## Jupyter Notebook
#
# ### What is Jupyter Notebook?
#
# Jupyter Notebook is an open source web application used to create and share documents that contain ...
# - live code
# - equations
# - visualizations
# - text.
#
# The Notebook extends the console-based approach to interactive computing.
#
# Jupyter Notebook is a web-based application for the whole computation process:--  developing, documenting, executing code, and communicating the results.
#
# Jupyter Notebook is a spin-off from the IPython project, and is maintained by the open-source community at **Project Jupyter** -- http://jupyter.org/
#
# <br>
#
# ### What is the value of using Jupyter Notebook?
#
# Jupyter Notebook offers these benefits...
#
# **A Web Application**: a browser-based tool for interactive authoring of documents -  combining text, mathematics, code, computations and rich media output.
#
# **Notebook Documents**: a representation of all content visible in the web application, including inputs and outputs of computations, explanatory text, mathematics, images, and rich media representations of objects.
#
# We’ll also install Jupyter Notebook in VS Code, to use directly inside the IDE, to have a single place to work from as we go.
#
# <br>

# %% [markdown]
# ### Installing Jupyter Notebook
#
# #### Install Jupyter in the Terminal ...
#
# In your bash terminal, type
#
# ```python
#     pip install jupyter notebook
# ```
#
# > Note: -- For MacOS users please remember to type `pip3`
#
# #### Install Jupyter in VS Code ...
#
# Make sure you’re in the correct directory, and type "`code .`" to open VS Code in that directory.
#
# Add the following VS Code Extensions by Microsoft: -
# -   Jupyter
# -   Jupyter Keymap
# -   Jupyter Notebook Renderer
# -   Jupyter Slide Show
# -   Jupyter Cell Tags
#
# <br>

# %% [markdown]
# ### How to start Jupyter Notebook Server
#
# Navigate to the correct directory in your terminal.
#
# Type "`jupyter notebook`" in your terminal and press enter.
#
# You should see something like this.
#
# ![Jupiter Notebook Server](./images/JupyterNotebookServer.jpg)
#
# <br>
#
# Clicking on an existing Notebook (a file with an `.ipynb` extension) should open a screen like this.
#
# ![Open an existing Notebook](./images/runningExistingNotebook.png)
#
# <br>
#
# Starting a new kernel should open  a screen like this one.
#
# ![Starting a new Kernel](./images/startNewKernel.jpg)
#
# <br>
#
# ### Using Jupyter Notebook in VS Code
#
# -   Make sure you’re in the correct directory in the your terminal
# -   Open VS Code through the terminal (type `code .`)
# -   Either Initialize Jupyter Notebook from the VS Code internal console; This will open the web interface (type jupyter notebook)
#
#         -- OR –-
#
# -   To use Jupyter Notebook inside VS Code, simply create  a new file with the "`.ipynb`" extension. You should see something like this
#
# ![Jupyter Notebook in VS Code](./images/jupyter_in_vscode.png)
#
# <br>
#
# ### Read more about Jupyter Notebook
#
# -   [The Jupyter Notebooks Project](https://jupyter.org)
# -   [Jupyter Notebook Quick Start Guide](https://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/index.html)
# -   [How to Use Jupyter Notebook: A Beginner’s Tutorial](https://www.dataquest.io/blog/jupyter-notebook-tutorial)
# -   [Excellent Article on beautifying Jupyter Notebooks](https://towardsdatascience.com/enrich-your-jupyter-notebook-with-these-tips-55c8ead25255)
#
# <br>

# %% [markdown]
# ---
#
# ## Review Questions:-
#
# - What kind of language is Python considered?
# - What’s a natural language?
# - What are Algorithms?
# - What is the program we use to write Python in?
# - What’s the file extension of a Python file?
# - What is the area called where we put in our commands?
# - What is the #1 rule of coding / debugging?
#
# <br>
#
# ---

# %% [markdown]
# ## Summary
#
# In this section we were introduced to the intersection of Data Analytics and Python.
#
# We looked at ... Python and two ways to code Python;
#
# We touched on Debugging;
#
# And we looked at achieving easier production flow in Jupyter Notebook.
#     -   What is Jupyter Notebook
#     -   How to install Jupyter Notebook
#     -   And how to use Jupyter Notebook
